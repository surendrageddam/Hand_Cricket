# %%
import os,glob,shutil
import random
import tensorflow as tf
import numpy as np
from PIL import Image
import cv2
import pandas as pd

# %%
train_path = 'Hand_Pictures\train'
test_path = 'Hand_Pictures\test'

# %%
# train_batches = tf.keras.preprocessing.image.ImageDataGenerator(
#     preprocessing_function=tf.keras.applications.vgg16.preprocess_input).flow_from_directory('Hand_Pictures\train', target_size=(224,224), 
#                     classes=['five','four','one','three','two'], batch_size=10)
# test_batches = tf.keras.preprocessing.image.ImageDataGenerator(
#     preprocessing_function=tf.keras.applications.vgg16.preprocess_input).flow_from_directory("Hand_Pictures\test", target_size=(224,224), 
#                     classes=['one','two','three','four','five'], batch_size=10)
# Out:
# Found 0 images belonging to 5 classes.
# Found 0 images belonging to 5 classes.

# %%
import pathlib

# %%
dirs = pathlib.Path('Hand_Pictures/train')
dirs_2= pathlib.Path('Hand_Pictures/test')

# %%
list(dirs.glob('*/*.jpg'))[:5]
# Out:
# [WindowsPath('Hand_Pictures/train/five/five_10.jpg'),
#  WindowsPath('Hand_Pictures/train/five/five_100.jpg'),
#  WindowsPath('Hand_Pictures/train/five/five_102.jpg'),
#  WindowsPath('Hand_Pictures/train/five/five_103.jpg'),
#  WindowsPath('Hand_Pictures/train/five/five_105.jpg')]

# %%
n_1 = list(dirs.glob('one/*'))
n_2= list(dirs.glob('two/*'))
n_3 = list(dirs.glob('three/*'))
n_4 = list(dirs.glob('four/*'))
n_5 = list(dirs.glob('five/*'))

# %%
n_1t = list(dirs_2.glob('one/*'))
n_2t= list(dirs_2.glob('two/*'))
n_3t = list(dirs_2.glob('three/*'))
n_4t = list(dirs_2.glob('four/*'))
n_5t = list(dirs_2.glob('five/*'))

# %%
Image.open(n_1[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x2249F7C2070>

# %%
dictionary = {
    'one':n_1,
    'two':n_2,
    'three':n_3,
    'four':n_4,
    'five':n_5
}

# %%
dictionary2 = {
    'one':n_1t,
    'two':n_2t,
    'three':n_3t,
    'four':n_4t,
    'five':n_5t
}

# %%
img = cv2.imread(str(n_1[0]))
img.shape,img
# Out:
# ((480, 640, 3),
#  array([[[85, 95, 89],
#          [85, 95, 89],
#          [85, 96, 88],
#          ...,
#          [54, 60, 49],
#          [55, 58, 49],
#          [55, 58, 49]],
#
#         [[85, 95, 89],
#          [85, 95, 89],
#          [85, 96, 88],
#          ...,
#          [53, 59, 48],
#          [54, 57, 48],
#          [54, 57, 48]],
#
#         [[83, 96, 88],
#          [83, 96, 88],
#          [83, 96, 88],
#          ...,
#          [51, 59, 48],
#          [52, 58, 47],
#          [52, 58, 47]],
#
#         ...,
#
#         [[76, 91, 83],
#          [76, 91, 83],
#          [75, 89, 83],
#          ...,
#          [56, 61, 52],
#          [56, 60, 54],
#          [56, 60, 54]],
#
#         [[76, 91, 83],
#          [76, 91, 83],
#          [78, 91, 83],
#          ...,
#          [55, 59, 53],
#          [55, 59, 54],
#          [55, 59, 54]],
#
#         [[76, 91, 83],
#          [76, 91, 83],
#          [78, 91, 83],
#          ...,
#          [55, 59, 53],
# ...

# %%
for label,img in dictionary.items():
    for image in img:
        read_img = cv2.imread(str(image))
        resized_img = cv2.resize(read_img,(224,224))
        x_train.append(resized_img)
        y_train.append(label)

# %%
len(x_train),len(y_train)
# Out:
# (850, 850)

# %%
x_test = []
y_test =[]
for label,img in dictionary2.items():
    for image in img:
        read_img = cv2.imread(str(image))
        resized_img = cv2.resize(read_img,(224,224))
        x_test.append(resized_img)
        y_test.append(label)

# %%
len(x_test),len(y_test)
# Out:
# (150, 150)

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-70961c855c49> in <module>
#       1 x_train = np.array(x_train)
#       2 y_train = np.array(y_train)
# ----> 3 x_train.type
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
X_train_ = x_train/255
Y_train = y_train/255
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-4c76819d5d53> in <module>
#       1 X_train_ = x_train/255
# ----> 2 Y_train = y_train/255
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
X_train
